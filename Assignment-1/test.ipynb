# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
import nltk
import re
from nltk.stem import WordNetLemmatizer, PorterStemmer
from tqdm import tqdm

# %%
TRAIN_DATA_PATH = "Data/train.csv"
NUM_FOLDS = 5
FRACTION_DATA = 0.1

stopwords = nltk.corpus.stopwords.words('english')
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()

# %%
def check_deps():
    nltk.download('stopwords')
    nltk.download("wordnet")
    nltk.download("omw-1.4")
    return True

# %%
class DataLoader:
    def __init__(self, train_data_path):
        self.df = pd.read_csv(train_data_path)
        self.vectorizer = TfidfVectorizer()
        self.sample_data()
        self.clean_data()
        _ = self.vectorizer.fit_transform(self.df["profile"])


    def sample_data(self):
        self.df = self.df.sample(frac=FRACTION_DATA)
        X,y = self.df.drop("profession", axis=1), self.df["profession"]
        over = RandomOverSampler()
        under = RandomUnderSampler()
        X_sampled, y_sampled = over.fit_resample(X, y)
        X_sampled["profession"] = y_sampled
        self.df = X_sampled
    
    def clean_data(self):
        profiles = self.df["profile"]
        cleaned_profiles = []
        for profile in tqdm(profiles):
            profile = re.sub(r'[^\w\s]', ' ', profile)
            profile = re.sub(r'\d+', ' ', profile)
            profile = profile.lower()
            profile = profile.split()
            profile = [stemmer.stem(word) for word in profile if not word in set(stopwords)]
            profile = [lemmatizer.lemmatize(word) for word in profile if not word in set(stopwords)]
            profile = ' '.join(profile)
            cleaned_profiles.append(profile)
        self.df["profile"] = cleaned_profiles

    def vectorize_data(self, data):
        return self.vectorizer.transform(data)
    
    def get_X_and_y(self,data_df):
        X = data_df.drop("profession", axis=1)
        y = data_df["profession"]
        X_vec = self.vectorize_data(data_df["profile"])
        return X_vec, y

# %%
check_deps()

data_loader = DataLoader(train_data_path=TRAIN_DATA_PATH)
df = data_loader.df

kf = KFold(n_splits=NUM_FOLDS)
## Currently considering only one fold here
train_index, val_index = next(kf.split(df))
train_data = df.iloc[train_index]
val_data = df.iloc[val_index]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/kshitij/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/kshitij/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/kshitij/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# 100%|██████████| 107744/107744 [02:27<00:00, 729.98it/s]

# %%
X_train_vec, _ = data_loader.get_X_and_y(train_data)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# /home/kshitij/Documents/GitHub/COL772-NLP-Assignments/Assignment-1/test.ipynb Cell 6 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/home/kshitij/Documents/GitHub/COL772-NLP-Assignments/Assignment-1/test.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> X_train_vec, _ = data_loader.get_X_and_y(train_data)
#       <a href='vscode-notebook-cell:/home/kshitij/Documents/GitHub/COL772-NLP-Assignments/Assignment-1/test.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> # make dataframe of tfidf
# ----> <a href='vscode-notebook-cell:/home/kshitij/Documents/GitHub/COL772-NLP-Assignments/Assignment-1/test.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> X_train_vec = pd.DataFrame(X_train_vec.toarray(), columns=data_loader.vectorizer.get_feature_names())
#
# File ~/.local/lib/python3.8/site-packages/scipy/sparse/_compressed.py:1051, in _cs_matrix.toarray(self, order, out)
#    1049 if out is None and order is None:
#    1050     order = self._swap('cf')[0]
# -> 1051 out = self._process_toarray_args(order, out)
#    1052 if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1053     raise ValueError('Output array must be C or F contiguous')
#
# File ~/.local/lib/python3.8/site-packages/scipy/sparse/_base.py:1288, in spmatrix._process_toarray_args(self, order, out)
#    1286     return out
#    1287 else:
# -> 1288     return np.zeros(self.shape, dtype=self.dtype, order=order)
#
# MemoryError: Unable to allocate 21.5 GiB for an array with shape (86688, 33354) and data type float64

# %%
data_loader.vectorizer.get_feature_names()
# Out:
# /home/kshitij/.local/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['_blank',
#  '_john_harrison',
#  '_niptuck',
#  '_wpnonc',
#  '_x',
#  'aa',
#  'aaa',
#  'aaaaj',
#  'aaai',
#  'aaal',
#  'aaba',
#  'aabha',
#  'aac',
#  'aacd',
#  'aachen',
#  'aacp',
#  'aacr',
#  'aacsb',
#  'aad',
#  'aag',
#  'aagaard',
#  'aagt',
#  'aaha',
#  'aahivm',
#  'aai',
#  'aalborg',
#  'aalto',
#  'aamft',
#  'aamo',
#  'aan',
#  'aanchal',
#  'aanp',
#  'aao',
#  'aap',
#  'aarburg',
#  'aarhu',
#  'aaron',
#  'aaronshom',
#  'aarp',
#  'aarrestad',
#  'aaryan',
#  'aashish',
#  'aasld',
#  'aasn',
#  'aatf',
#  'aatseel',
#  'aatsp',
#  'aau',
#  'aauw',
#  'ab',
#  'aba',
#  'ababa',
#  'abacanurseri',
#  'aback',
#  'abad',
#  'abakanowicz',
#  'abandon',
#  'abang',
#  'abb',
#  'abba',
#  'abbey',
#  'abbi',
#  'abbott',
#  'abc',
#  'abcnew',
#  'abd',
#  'abdellah',
#  'abdellaoui',
#  'abdic',
#  'abdomen',
#  'abdomin',
#  'abdominoplasti',
#  'abduct',
#  'abductor',
#  'abdulazez',
#  'abdurasulov',
#  'abeer',
#  'abel',
#  'abella',
#  'abelo',
#  'abend',
#  'abercrombi',
#  'aberdeen',
#  'aberdeenshir',
#  'aberhart',
#  'aberystwyth',
#  'abet',
#  'abhijeet',
#  'abi',
#  'abid',
#  'abidi',
#  'abigail',
#  'abigailesman',
#  'abil',
#  'abilen',
#  'abim',
#  'abinbev',
#  'abingdon',
#  'abington',
#  'abitar',
#  'abiva',
#  'abl',
#  'ablan',
#  'ablat',
#  'abli',
#  'ablut',
#  'abmg',
#  'abnorm',
#  'aboard',
#  'abogado',
#  'abolit',
#  'abolitionist',
#  'abom',
#  'aborigin',
#  'abort',
#  'abound',
#  'abp',
#  'abraczinska',
#  'abraham',
#  'abram',
#  'abramochkin',
#  'abrar',
#  'abreast',
#  'abri',
#  'abril',
#  'abroad',
#  'abrupt',
#  'abruzzo',
#  'absenc',
#  'absent',
#  'absn',
#  'absolut',
#  'absolv',
#  'absorb',
#  'absorpt',
#  'abstain',
#  'abstract',
#  'abstractionist',
#  'absurd',
#  'abu',
#  'abuja',
#  'abund',
#  'abundo',
#  'abus',
#  'abvp',
#  'ac',
#  'aca',
#  'acad',
#  'academ',
#  'academi',
#  'academia',
#  'academician',
#  'acadia',
#  'acap',
#  'accad',
#  'accademia',
#  'acceler',
#  'accent',
#  'accentur',
#  'accept',
#  'acceptor',
#  'access',
#  'accessori',
#  'accid',
#  'accident',
#  'acclaim',
#  'accolad',
#  'accommod',
#  'accompani',
#  'accompanist',
#  'accomplish',
#  'accomplsih',
#  'accord',
#  'accordion',
#  'account',
#  'accp',
#  'accredit',
#  'accru',
#  'accultur',
#  'accumben',
#  'accumul',
#  'accur',
#  'accuraci',
#  'accus',
#  'accustom',
#  'acda',
#  'acdc',
#  'acdemi',
#  'ace',
#  'acedo',
#  'acem',
#  'acento',
#  'acetyl',
#  'acf',
#  'acfa',
#  'acfproj',
#  'acg',
#  'ach',
#  'acha',
#  'achalasia',
#  'acharya',
#  'acheiv',
#  'achh',
#  'achiev',
#  'achil',
#  'aci',
#  'acid',
#  'acienc',
#  'ackerman',
#  'ackerson',
#  'acknowledg',
#  'ackroyd',
#  'acl',
#  'acla',
#  'aclu',
#  'acm',
#  'acn',
#  'aco',
#  'acor',
#  'acorn',
#  'acosta',
#  'acousmat',
#  'acoust',
#  'acp',
#  'acpa',
#  'acquaint',
#  'acquir',
#  'acquisit',
#  'acquitt',
#  'acr',
#  'acreag',
#  'across',
#  'acryl',
#  'acsa',
#  'acsm',
#  'act',
#  'acta',
#  'actingfrom',
#  'action',
#  'activ',
#  'activewear',
#  'activis',
#  'activist',
#  'activon',
#  'actor',
#  'actress',
#  'actual',
#  'actuari',
#  'actuat',
#  'actuel',
#  'acu',
#  'acumen',
#  'acupunctur',
#  'acupuncturist',
#  'acut',
#  'ad',
#  'ada',
#  'adabi',
#  'adair',
#  'adajan',
#  'adam',
#  'adama',
#  'adanma',
#  'adapt',
#  'adarsh',
#  'adbc',
#  'adbust',
#  'adc',
#  'add',
#  'add_us',
#  'adda',
#  'addenbrook',
#  'addi',
#  'addict',
#  'addison',
#  'addit',
#  'additon',
#  'address',
#  'adea',
#  'adeagbo',
#  'adejumobi',
#  'adel',
#  'adelaid',
#  'adelina',
#  'adelman',
#  'adelphi',
#  'adenocarcinoma',
#  'adenosin',
#  'adenovir',
#  'adept',
#  'adeya',
#  'adhd',
#  'adher',
#  'adhes',
#  'adi',
#  'adida',
#  'adikavi',
#  'adirondack',
#  'aditi',
#  'aditya',
#  'adjac',
#  'adjud',
#  'adjunct',
#  'adjust',
#  'adjut',
#  'adjuv',
#  'adkin',
#  'adler',
#  'adlerian',
#  'adlin',
#  'admin',
#  'administ',
#  'administr',
#  'admir',
#  'admira',
#  'admiss',
#  'admit',
#  'admma',
#  'adn',
#  'adnan',
#  'ado',
#  'adob',
#  'adolesc',
#  'adolph',
#  'adolphu',
#  'adomian',
#  'adoni',
#  'adopt',
#  'adopte',
#  'ador',
#  'adorn',
#  'adp',
#  'adr',
#  'adren',
#  'adrenalin',
#  'adrenoceptor',
#  'adria',
#  'adrian',
#  'adriana',
#  'adrianna',
#  'adriat',
#  'adrien',
#  'adrienn',
#  'adrogu',
#  'adroit',
#  'adroitli',
#  'adsri',
#  'adt',
#  'adult',
#  'adulter',
#  'adulteri',
#  'adulthood',
#  'adv',
#  'advanc',
#  'advantag',
#  'adventist',
#  'adventistangel',
#  'adventur',
#  'advers',
#  'adversari',
#  'advert',
#  'advertis',
#  'advic',
#  'advis',
#  'advise',
#  'advisor',
#  'advisori',
#  'advita',
#  'advoc',
#  'advocaci',
#  'advocar',
#  'adword',
#  'ae',
#  'aea',
#  'aeca',
#  'aecom',
#  'aefo',
#  'aegean',
#  'aegl',
#  'aeguy',
#  'aeliu',
#  'aemba',
#  'aeon',
#  'aera',
#  'aerc',
#  'aerial',
#  'aero',
#  'aerob',
#  'aerodynam',
#  'aeron',
#  'aeronaut',
#  'aerosmith',
#  'aerosol',
#  'aerospac',
#  'aesthet',
#  'aesthetic',
#  'aesthetica',
#  'aesthetix',
#  'aetna',
#  'af',
#  'afa',
#  'afaa',
#  'afac',
#  'afar',
#  'afb',
#  'aff',
#  'affair',
#  'affect',
#  'affection',
#  'affidavit',
#  'affili',
#  'affiliationsangela',
#  'affin',
#  'affirm',
#  'affliat',
#  'afflict',
#  'afford',
#  'afghah',
#  'afghan',
#  'afghani',
#  'afghanistan',
#  'afi',
#  'afiap',
#  'aficionado',
#  'afield',
#  'afir',
#  'afirst',
#  'afl',
#  'aflac',
#  'afleg',
#  'afloat',
#  'afn',
#  'aforement',
#  'afosr',
#  'afraid',
#  'afresh',
#  'afri',
#  'africa',
#  'african',
#  'africana',
#  'afriesen',
#  'afrika',
#  'afrikaan',
#  'afrikan',
#  'afriqu',
#  'afriyi',
#  'afrl',
#  'afro',
#  'afrobaromet',
#  'afscm',
#  'afset',
#  'afshin',
#  'afterglow',
#  'afterlif',
#  'afterlight',
#  'aftermarket',
#  'aftermath',
#  'afternoon',
#  'afterparti',
#  'afterschool',
#  'aftershock',
#  'aftertast',
#  'afterward',
#  'afterworld',
#  'aftonbladet',
#  'aftra',
#  'ag',
#  'aga',
#  'agarkar',
#  'agarw',
#  'agbabi',
#  'age',
#  'agegnehu',
#  'ageism',
#  'ageless',
#  'agenc',
#  'agenda',
#  'agent',
#  'ageofantichrist',
#  'ager',
#  'agewel',
#  'agfa',
#  'aggarw',
#  'aggreg',
#  'aggregaion',
#  'aggress',
#  'agh',
#  'aghor',
#  'agi',
#  'agil',
#  'agn',
#  'agnieszka',
#  'agnè',
#  'ago',
#  'agonda',
#  'agonist',
#  'agora',
#  'agra',
#  'agrarian',
#  'agre',
#  'agreement',
#  'agrella',
#  'agri',
#  'agribusi',
#  'agricultur',
#  'agroforestri',
#  'agronom',
#  'agronomi',
#  'agrosci',
#  'agrégat',
#  'aguada',
#  'aguilar',
#  'agunot',
#  'ah',
#  'ah_cu',
#  'aha',
#  'ahaknap',
#  'ahdal',
#  'ahdoot',
#  'ahead',
#  'ahearn',
#  'ahec',
#  'ahemdabad',
#  'ahg',
#  'ahlbrandt',
#  'ahlfeld',
#  'ahm',
#  'ahmad',
#  'ahmadi',
#  'ahmedabad',
#  'ahn',
#  'ahna',
#  'ahperd',
#  'ahpra',
#  'ahrd',
#  'ahren',
#  'ahrq',
#  'ahu',
#  'ahuja',
#  'ai',
#  'aia',
#  'aiaa',
#  'aiadcadr',
#  'aiaeni',
#  'aib',
#  'aich',
#  'aicpa',
#  'aid',
#  'aida',
#  'aidan',
#  'aider',
#  'aidoma',
#  'aidoo',
#  'aiga',
#  'aikido',
#  'aikikai',
#  'aila',
#  'ailment',
#  'aim',
#  'aimhub',
#  'aini',
#  'ainsworth',
#  'aip',
#  'aipiari',
#  'air',
#  'airbas',
#  'airborn',
#  'airbrush',
#  'aircraft',
#  'airfield',
#  'airi',
#  'airlin',
#  'airman',
#  'airplan',
#  'airplay',
#  'airport',
#  'airship',
#  'airshow',
#  'airway',
#  'aisenberg',
#  'aisl',
#  'aistat',
#  'ait',
#  'aitken',
#  'aium',
#  'aix',
#  'ajac',
#  'ajami',
#  'ajaneesh',
#  'ajanta',
#  'ajax',
#  'ajay',
#  'ajaz',
#  'aji',
#  'ajit',
#  'ajitesh',
#  'ajmer',
#  'ajpizzomd',
#  'ak',
#  'aka',
#  'akademi',
#  'akademia',
#  'akademisch',
#  'akan',
#  'akanksha',
#  'akash',
#  'akashacm',
#  'akb',
#  'akbar',
#  'akchoté',
#  'aker',
#  'akhanda',
#  'akhbar',
#  'akhila',
#  'akhtar',
#  'aki',
#  'akiko',
#  'akin',
#  'akkad',
#  'akkari',
#  'akkaway',
#  'akram',
#  'akron',
#  'aksaz',
#  'aksen',
#  'aksiom',
#  'aksyon',
#  'akt',
#  'akua',
#  'akwei',
#  'akyol',
#  'al',
#  'ala',
#  'alaap',
#  'alabama',
#  'alabast',
#  'alain',
#  'alaina',
#  'alam',
#  'alameda',
#  'alamo',
#  'alamosa',
#  'alan',
#  'alana',
#  'alanmcfadyen',
#  'alann',
#  'alar',
#  'alarcon',
#  'alarm',
#  'alarmist',
#  'alasdair',
#  'alasfar',
#  'alaska',
#  'alaskan',
#  'alawi',
#  'alba',
#  'alban',
#  'albani',
#  'albeit',
#  'albemarl',
#  'albert',
#  'alberta',
#  'albertan',
#  'alberto',
#  'albion',
#  'albrecht',
#  'albu',
#  'album',
#  'albuquerqu',
#  'alburi',
#  'alc',
#  'alcala',
#  'alcatel',
#  'alchemist',
#  'alcohol',
#  'aldeburgh',
#  'alden',
#  'alder',
#  'alderdic',
#  'alderman',
#  'alderton',
#  'aldgat',
#  'aldo',
#  'aldrich',
#  'alea',
#  'aleatorio',
#  'alec',
#  'alecia',
#  'aled',
#  'alederlaw',
#  'aledo',
#  'aleist',
#  'alejandra',
#  'alejandro',
#  'aleksand',
#  'aleksandar',
#  'alemzew',
#  'alen',
#  'aleppo',
#  'alert',
#  'alessia',
#  'alex',
#  'alexa',
#  'alexand',
#  'alexandr',
#  'alexandra',
#  'alexandria',
#  'alexandrin',
#  'alexandro',
#  'alexflinn',
#  'alexi',
#  'alexian',
#  'alexiu',
#  'alfa',
#  'alfonso',
#  'alford',
#  'alfr',
#  'alfredo',
#  'algal',
#  'algebra',
#  'algeria',
#  'algerian',
#  'algorithm',
#  'algorithmica',
#  'algéri',
#  'alhotan',
#  'ali',
#  'alia',
#  'alibi',
#  'alic',
#  'alicant',
#  'alicia',
#  'alien',
#  'alif',
#  'align',
#  'alik',
#  'alimentum',
#  'alimoni',
#  'alina',
#  'alincolnblog',
#  'alingon',
#  'alipour',
#  'aliquippa',
#  'alireza',
#  'alisa',
#  'alisha',
#  'alison',
#  'alissa',
#  'alistair',
#  'aliv',
#  'alix',
#  'aliyah',
#  'aliz',
#  'alj',
#  'aljira',
#  'alkon',
#  'alla',
#  'allaboutlaw',
#  'allahabad',
#  'allan',
#  'allauddin',
#  'allcollegeessay',
#  'alleg',
#  'allegheni',
#  'allegi',
#  'allegor',
#  'allegori',
#  'allegro',
#  'allemandi',
#  'allen',
#  'allend',
#  'allensax',
#  'allerg',
#  'allergan',
#  'allergi',
#  'allevi',
#  'alley',
#  'alleyn',
#  'alli',
#  'allianc',
#  'alliant',
#  'allianz',
#  'allina',
#  'allison',
#  'allisonprang',
#  'alliter',
#  'allmon',
#  'alloc',
#  'allot',
#  'allow',
#  'alloy',
#  'allr',
#  'alltech',
#  'allud',
#  'allur',
#  'allus',
#  'allylnickel',
#  'alma',
#  'almanac',
#  'almeida',
#  'almoro',
#  'almost',
#  'almuna',
#  'aln',
#  'aloha',
#  'aloisiu',
#  'alok',
#  'alon',
#  'along',
#  'alongsid',
#  'alonzo',
#  'alopecia',
#  'aloud',
#  'alp',
#  'alpena',
#  'alpert',
#  'alpha',
#  'alphabet',
#  'alpharetta',
#  'alphonso',
#  'alphonsu',
#  'alpin',
#  'alreadi',
#  'alsan',
#  'also',
#  'alt',
#  'alta',
#  'altamont',
#  'alter',
#  'alterc',
#  'altermedia',
#  'altern',
#  'alternativecitytour',
#  'altfeld',
#  'althea',
#  'altheim',
#  'although',
#  'altman',
#  'altmuslim',
#  'altmuslimah',
#  'altnagelvin',
#  'alto',
#  'alton',
#  'altoona',
#  'altru',
#  'altruism',
#  'altruist',
#  'altstadt',
#  'altura',
#  'alum',
#  'alumin',
#  'aluminum',
#  'alumna',
#  'alumnu',
#  'alumnus',
#  'alura',
#  'alvarado',
#  'alvaren',
#  'alvi',
#  'alvin',
#  'alwarpet',
#  'alway',
#  'alwaya',
#  'alx',
#  'alyeska',
#  'alyn',
#  'alyosha',
#  'alyson',
#  'alyssa',
#  'alyssabrown',
#  'alz',
#  'alzheim',
#  'alzherim',
#  'ama',
#  'amador',
#  'amalgam',
#  'amalya',
#  'aman',
#  'amanda',
#  'amani',
#  'amant',
#  'amaranth',
#  'amaranthart',
#  'amaretto',
#  'amarillo',
#  'amass',
#  'amat',
#  'amata',
#  'amateur',
#  'amatruda',
#  'amaz',
#  'amazingli',
#  'amazon',
#  'amazonian',
#  'amb',
#  'amba',
#  'ambacht',
#  'ambalika',
#  'ambarish',
#  'ambassador',
#  'ambati',
#  'ambato',
#  'ambattur',
#  'ambedkar',
#  'ambedkarit',
#  'amber',
#  'ambidextrist',
#  'ambient',
#  'ambigu',
#  'ambit',
#  'ambiti',
#  'ambivert',
#  'ambler',
#  'amboy',
#  'ambros',
#  'ambrotyp',
#  'ambul',
#  'ambulatori',
#  'amburgey',
#  'ame',
#  'amelia',
#  'amelior',
#  'amen',
#  'amend',
#  'amer',
#  'amerasia',
#  'ameri',
#  'ameriacan',
#  'america',
#  'american',
#  'americana',
#  'americorp',
#  'amerigroup',
#  'amerihealth',
#  'ameubl',
#  'amezaliwa',
#  'amgen',
#  'amherst',
#  'ami',
#  'amia',
#  'amic',
#  'amica',
#  'amidst',
#  'amigo',
#  'amin',
#  'amino',
#  'aminul',
#  'amir',
#  'amirghaferi',
#  'amirnia',
#  'amish',
#  'amison',
#  'amit',
#  'amitav',
#  'amitava',
#  'amiti',
#  'ammal',
#  'amnesti',
#  'amnewyork',
#  'amniot',
#  'amo',
#  'amoeboid',
#  'amogh',
#  'amol',
#  'among',
#  'amongst',
#  'amonst',
#  'amor',
#  'amori',
#  'amount',
#  'amp',
#  'amphibian',
#  'amphitheatr',
#  'amplab',
#  'amplif',
#  'amplifi',
#  'amput',
#  'ampute',
#  'amrit',
#  'amritsar',
#  'amsterdam',
#  'amunategui',
#  'amundson',
#  'amus',
#  'amuthan',
#  'amwaj',
#  'amyfaithho',
#  'amyloidosi',
#  'amythomasdesign',
#  'américa',
#  'an',
#  'ana',
#  'anadol',
#  'anadolu',
#  'anaemia',
#  'anaerob',
#  'anaesthesia',
#  'anaesthet',
#  'anaesthetist',
#  'anaheim',
#  ...]
