# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score, roc_auc_score, roc_curve
import nltk
import re
from nltk.stem import WordNetLemmatizer, PorterStemmer
from tqdm import tqdm

# %%
def check_deps():
    nltk.download('stopwords')
    nltk.download("wordnet")
    nltk.download("omw-1.4")
    return True
check_deps()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/kshitijalwadhi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/kshitijalwadhi/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/kshitijalwadhi/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
TRAIN_DATA_PATH = "Data/train.csv"
NUM_FOLDS = 5
FRACTION_DATA = 0.1

stopwords = nltk.corpus.stopwords.words('english')
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()

# %%
df = pd.read_csv(TRAIN_DATA_PATH)
df = df.sample(frac=FRACTION_DATA, random_state = 42)
df.head()
# Out:
#                                                   profile  profession
# 30016   He obtained his medical school training at the...   physician
# 14622   In 2007 he naturalised as a British citizen ke...    composer
# 97157   While in Austin he worked his way up through m...    comedian
# 114197  Her primary research interest is in financial ...   professor
# 16319   She is a graduate of NYU’s Science, Health and...  journalist

# %%
# get all professions
professions = df["profession"].unique()
professions
# Out:
# array(['physician', 'composer', 'comedian', 'professor', 'journalist',
#        'paralegal', 'nurse', 'attorney', 'teacher', 'psychologist',
#        'dietitian', 'photographer', 'surgeon', 'poet', 'rapper',
#        'software_engineer', 'architect', 'dentist', 'model', 'pastor',
#        'filmmaker', 'painter', 'accountant', 'dj', 'yoga_teacher',
#        'interior_designer', 'chiropractor', 'personal_trainer'],
#       dtype=object)

# %%
# get counts
df["profession"].value_counts()
# Out:
# professor            3822
# physician            1240
# attorney             1104
# photographer          829
# nurse                 620
# journalist            619
# psychologist          598
# teacher               509
# dentist               469
# surgeon               445
# architect             322
# painter               258
# filmmaker             220
# model                 219
# poet                  219
# software_engineer     216
# accountant            177
# composer              170
# dietitian             136
# comedian               95
# pastor                 87
# chiropractor           82
# paralegal              63
# rapper                 62
# personal_trainer       58
# dj                     52
# yoga_teacher           48
# interior_designer      47
# Name: profession, dtype: int64

# %%
# # make every non-professor in profession
# df["profession"] = df["profession"].apply(lambda x: "non-professor" if x!="professor" else x)

# %%
# get classwise count of professions
df["profession"].value_counts()
# Out:
# professor            3822
# physician            1240
# attorney             1104
# photographer          829
# nurse                 620
# journalist            619
# psychologist          598
# teacher               509
# dentist               469
# surgeon               445
# architect             322
# painter               258
# filmmaker             220
# model                 219
# poet                  219
# software_engineer     216
# accountant            177
# composer              170
# dietitian             136
# comedian               95
# pastor                 87
# chiropractor           82
# paralegal              63
# rapper                 62
# personal_trainer       58
# dj                     52
# yoga_teacher           48
# interior_designer      47
# Name: profession, dtype: int64

# %%
def

# %%
def clean_data(df):
    profiles = df["profile"]
    cleaned_profiles = []
    for profile in tqdm(profiles):
        profile = re.sub(r'[^\w\s]', ' ', profile)
        profile = profile.lower()
        profile = profile.split()
        profile = [stemmer.stem(word) for word in profile if not word in set(stopwords)]
        profile = [lemmatizer.lemmatize(word) for word in profile if not word in set(stopwords)]
        profile = ' '.join(profile)
        cleaned_profiles.append(profile)
    df["cleaned_profile"] = cleaned_profiles
    return df

# %%
professions_sorted = sorted(professions)

# %%
def add_profession_one_hot(df):
    # add column for each profession
    df["presence"] = 1
    for i, row in tqdm(df.iterrows()):
        presence_list = [1] * len(professions_sorted)    
        profile = row["profile"]
        for w in profile.split():
            w = w.lower()
            if w in professions:
                presence_list[professions_sorted.index(w)] += 1
        df.loc[i, ] = presence_list 
    return df

# %%
df = clean_data(df)
# Out:
# 100%|██████████| 12786/12786 [00:09<00:00, 1407.50it/s]

# %%
# df = add_profession_one_hot(df)

# %%
df
# Out:
#                                                   profile    profession  \
# 30016   He obtained his medical school training at the...     physician
# 14622   In 2007 he naturalised as a British citizen ke...      composer
# 97157   While in Austin he worked his way up through m...      comedian
# 114197  Her primary research interest is in financial ...     professor
# 16319   She is a graduate of NYU’s Science, Health and...    journalist
# ...                                                   ...           ...
# 66210   He holds an MA in English literature from Sout...     professor
# 123466  As a musician herself, Renuka realizes the imp...      attorney
# 60158   She graduated with honors from University Of I...         nurse
# 91322   He specializes in creating imaginative and tho...  photographer
# 90653   Her average patient rating is 4.0 stars out of...     physician
#
#                                           cleaned_profile
# 30016   obtain medic school train univers texa medic b...
# 14622   2007 naturalis british citizen keep spanish ci...
# 97157   austin work way major venu showcas produc mult...
# 114197  primari research interest financi account part...
# 16319   graduat nyu scienc health environment report p...
# ...                                                   ...
# 66210   hold english literatur south dakota state univ...
# 123466  musician renuka realiz import intellectu prope...
# 60158   graduat honor univers illinoi chicago health s...
# 91322   special creat imagin thought imag sell product...
# 90653   averag patient rate 4 0 star 5 dr kimbrow take...
#
# [12786 rows x 3 columns]

# %%
vectorizer = TfidfVectorizer(ngram_range = (1,2), max_features=10000, sublinear_tf=True)
vectorizer.fit_transform(df["cleaned_profile"])
# Out:
# <12786x10000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 469439 stored elements in Compressed Sparse Row format>

# %%
# get number of features in vectorizer
len(vectorizer.get_feature_names())
# Out:
# /opt/homebrew/lib/python3.10/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# 10000

# %%
def sample_data(df):
    X, y = df.drop("profession", axis=1), df["profession"]
    over = RandomOverSampler()
    X_sampled, y_sampled = over.fit_resample(X, y)
    X_sampled["profession"] = y_sampled
    return X_sampled

# %%
def get_X_and_y(data_df):
    y = data_df["profession"]
    X_vec = vectorizer.transform(data_df["cleaned_profile"])
    return X_vec, y
X_vec, y = get_X_and_y(df)

# %%
kf = KFold(n_splits=NUM_FOLDS, shuffle=False)
train_index, val_index = next(kf.split(df))
train_data = df.iloc[train_index]
val_data = df.iloc[val_index]

# %%
# def combine_high_occ_professions(df):
#     professor_df = df[df["profession"]=="professor"]
#     # empty df
#     profile_arr = professor_df["profile"].values
#     cleaned_profile_arr = professor_df["cleaned_profile"].values
#     profession_arr = professor_df["profession"].values

#     profile_arr = np.array([profile_arr[i:i+3] for i in range(0, len(profile_arr), 3)])
#     cleaned_profile_arr = np.array([cleaned_profile_arr[i:i+3] for i in range(0, len(cleaned_profile_arr), 3)])
#     profession_arr = np.array([profession_arr[i:i+3] for i in range(0, len(profession_arr), 3)])

# %%
# get value counts of professions
df["profession"].value_counts()
# Out:
# professor            3822
# physician            1240
# attorney             1104
# photographer          829
# nurse                 620
# journalist            619
# psychologist          598
# teacher               509
# dentist               469
# surgeon               445
# architect             322
# painter               258
# filmmaker             220
# model                 219
# poet                  219
# software_engineer     216
# accountant            177
# composer              170
# dietitian             136
# comedian               95
# pastor                 87
# chiropractor           82
# paralegal              63
# rapper                 62
# personal_trainer       58
# dj                     52
# yoga_teacher           48
# interior_designer      47
# Name: profession, dtype: int64

# %%
def augment_data(df, profession, target_num):
    profiles = df[df["profession"]==profession]["profile"].values
    # split

# %%
train_data = sample_data(train_data)

# %%
# shuffle data
train_data = train_data.sample(frac=1, random_state = 42).reset_index(drop=True)
val_data = val_data.sample(frac=1, random_state = 42).reset_index(drop=True)

# %%
X_train_vec, y_train = get_X_and_y(train_data)

# %%
model = MultinomialNB(alpha=0.7).fit(X_train_vec, y_train)

# %%
X_val_vec, y_val = get_X_and_y(val_data)

y_pred = model.predict(X_val_vec)

print(metrics.accuracy_score(y_val, y_pred))
# Out:
# 0.5977326035965598

# %%
# calculate micro F1 and macro F1
print("Micro F1: ", metrics.f1_score(y_val, y_pred, average='micro'))
print("Macro F1: ", metrics.f1_score(y_val, y_pred, average='macro'))
# Out:
# Micro F1:  0.7130570758405004
# Macro F1:  0.6309011590186797

# %%
# get average
print("Average F1: ", (metrics.f1_score(y_val, y_pred, average='micro') + metrics.f1_score(y_val, y_pred, average='macro'))/2)
# Out:
# Average F1:  0.67197911742959

# %%
# get classwise accuracy
print(metrics.classification_report(y_val, y_pred))
# Out:
#                    precision    recall  f1-score   support
#
#        accountant       0.57      0.77      0.66        35
#         architect       0.58      0.60      0.59        70
#          attorney       0.87      0.82      0.84       253
#      chiropractor       0.55      0.79      0.65        14
#          comedian       0.48      0.61      0.54        18
#          composer       0.63      0.76      0.69        34
#           dentist       0.90      0.81      0.85        89
#         dietitian       0.56      0.80      0.66        25
#                dj       0.75      0.38      0.50         8
#         filmmaker       0.61      0.73      0.67        48
# interior_designer       0.75      0.60      0.67        10
#        journalist       0.56      0.63      0.59       118
#             model       0.94      0.75      0.83        40
#             nurse       0.69      0.72      0.70       119
#           painter       0.52      0.80      0.63        41
#         paralegal       0.60      0.23      0.33        13
#            pastor       0.44      0.69      0.54        16
#  personal_trainer       0.43      0.55      0.48        11
#      photographer       0.69      0.77      0.73       162
#         physician       0.78      0.69      0.73       247
#              poet       0.48      0.67      0.56        46
#         professor       0.90      0.74      0.81       789
#      psychologist       0.63      0.56      0.59       115
#            rapper       0.50      0.44      0.47         9
# software_engineer       0.44      0.73      0.55        44
#           surgeon       0.55      0.66      0.60        85
#           teacher       0.38      0.58      0.46        84
#      yoga_teacher       0.83      0.67      0.74        15
#
#          accuracy                           0.71      2558
#         macro avg       0.63      0.66      0.63      2558
#      weighted avg       0.74      0.71      0.72      2558

# %%
# get prediction distribution when original label is professor
for occ in professions:
    print("#####################")
    print("Actual label: ", occ)
    print("#####################")
    selected_pred = y_pred[y_val==occ]
    print(pd.Series(selected_pred).value_counts())
    print()
# Out:
# #####################
# Actual label:  physician
# #####################
# physician           170
# professor            18
# surgeon              17
# nurse                12
# psychologist          6
# dietitian             6
# journalist            4
# dentist               4
# chiropractor          3
# personal_trainer      2
# filmmaker             1
# attorney              1
# photographer          1
# rapper                1
# pastor                1
# dtype: int64
#
# #####################
# Actual label:  composer
# #####################
# composer     26
# filmmaker     3
# rapper        1
# teacher       1
# painter       1
# pastor        1
# professor     1
# dtype: int64
#
# #####################
# Actual label:  comedian
# #####################
# comedian        11
# photographer     2
# psychologist     1
# dietitian        1
# composer         1
# model            1
# poet             1
# dtype: int64
#
# #####################
# Actual label:  professor
# #####################
# professor            580
# surgeon               23
# software_engineer     22
# psychologist          22
# teacher               19
# architect             18
# journalist            17
# poet                  16
# attorney              12
# nurse                 11
# photographer           9
# painter                9
# physician              8
# filmmaker              6
# composer               5
# accountant             3
# dietitian              2
# personal_trainer       2
# pastor                 2
# rapper                 1
# comedian               1
# yoga_teacher           1
# dtype: int64
#
# #####################
# Actual label:  journalist
# #####################
# journalist           74
# photographer         11
# filmmaker             5
# teacher               5
# poet                  5
# professor             4
# attorney              4
# software_engineer     3
# composer              2
# accountant            2
# comedian              1
# architect             1
# pastor                1
# dtype: int64
#
# #####################
# Actual label:  paralegal
# #####################
# attorney     7
# paralegal    3
# teacher      2
# professor    1
# dtype: int64
#
# #####################
# Actual label:  nurse
# #####################
# nurse           86
# physician        9
# teacher          5
# professor        5
# dietitian        3
# comedian         2
# accountant       2
# attorney         2
# poet             1
# psychologist     1
# surgeon          1
# filmmaker        1
# rapper           1
# dtype: int64
#
# #####################
# Actual label:  attorney
# #####################
# attorney             207
# teacher                7
# accountant             6
# professor              6
# journalist             6
# photographer           3
# comedian               3
# architect              3
# pastor                 2
# poet                   2
# software_engineer      2
# paralegal              2
# painter                1
# filmmaker              1
# dietitian              1
# psychologist           1
# dtype: int64
#
# #####################
# Actual label:  teacher
# #####################
# teacher         49
# poet             5
# professor        5
# pastor           4
# photographer     4
# journalist       3
# composer         3
# filmmaker        2
# psychologist     2
# model            1
# architect        1
# attorney         1
# comedian         1
# accountant       1
# physician        1
# nurse            1
# dtype: int64
#
# #####################
# Actual label:  psychologist
# #####################
# psychologist    64
# professor       17
# nurse           13
# physician        7
# teacher          6
# journalist       3
# architect        1
# dentist          1
# accountant       1
# photographer     1
# yoga_teacher     1
# dtype: int64
#
# #####################
# Actual label:  dietitian
# #####################
# dietitian           20
# teacher              2
# surgeon              1
# nurse                1
# personal_trainer     1
# dtype: int64
#
# #####################
# Actual label:  photographer
# #####################
# photographer         125
# painter               13
# journalist            10
# teacher                5
# filmmaker              2
# comedian               1
# personal_trainer       1
# professor              1
# attorney               1
# interior_designer      1
# pastor                 1
# accountant             1
# dtype: int64
#
# #####################
# Actual label:  surgeon
# #####################
# surgeon             56
# physician           15
# teacher              4
# dentist              3
# psychologist         2
# personal_trainer     1
# professor            1
# nurse                1
# photographer         1
# journalist           1
# dtype: int64
#
# #####################
# Actual label:  poet
# #####################
# poet            31
# teacher          7
# pastor           2
# journalist       2
# photographer     2
# professor        1
# painter          1
# dtype: int64
#
# #####################
# Actual label:  rapper
# #####################
# rapper          4
# photographer    1
# dj              1
# comedian        1
# teacher         1
# poet            1
# dtype: int64
#
# #####################
# Actual label:  software_engineer
# #####################
# software_engineer    32
# architect             4
# teacher               2
# journalist            2
# dietitian             1
# poet                  1
# composer              1
# professor             1
# dtype: int64
#
# #####################
# Actual label:  architect
# #####################
# architect            42
# software_engineer    12
# photographer          4
# professor             4
# teacher               3
# accountant            2
# attorney              1
# painter               1
# composer              1
# dtype: int64
#
# #####################
# Actual label:  dentist
# #####################
# dentist         72
# physician        6
# chiropractor     6
# surgeon          3
# dietitian        1
# psychologist     1
# dtype: int64
#
# #####################
# Actual label:  model
# #####################
# model           30
# photographer     2
# painter          2
# accountant       2
# comedian         1
# filmmaker        1
# teacher          1
# architect        1
# dtype: int64
#
# #####################
# Actual label:  pastor
# #####################
# pastor               11
# teacher               2
# architect             1
# interior_designer     1
# journalist            1
# dtype: int64
#
# #####################
# Actual label:  filmmaker
# #####################
# filmmaker       35
# photographer     6
# journalist       5
# teacher          1
# composer         1
# dtype: int64
#
# #####################
# Actual label:  painter
# #####################
# painter              33
# photographer          6
# poet                  1
# software_engineer     1
# dtype: int64
#
# #####################
# Actual label:  accountant
# #####################
# accountant    27
# attorney       3
# professor      2
# journalist     2
# painter        1
# dtype: int64
#
# #####################
# Actual label:  dj
# #####################
# dj              3
# photographer    2
# comedian        1
# painter         1
# journalist      1
# dtype: int64
#
# #####################
# Actual label:  yoga_teacher
# #####################
# yoga_teacher    10
# teacher          4
# photographer     1
# dtype: int64
#
# #####################
# Actual label:  interior_designer
# #####################
# interior_designer    6
# photographer         1
# composer             1
# software_engineer    1
# teacher              1
# dtype: int64
#
# #####################
# Actual label:  chiropractor
# #####################
# chiropractor        11
# physician            2
# personal_trainer     1
# dtype: int64
#
# #####################
# Actual label:  personal_trainer
# #####################
# personal_trainer    6
# teacher             2
# dietitian           1
# psychologist        1
# architect           1
# dtype: int64

# %%
train_data_orig = df.iloc[train_index]
X_train_vec_orig, y_train_orig = get_X_and_y(train_data_orig)
y_pred_train_orig = model.predict(X_train_vec_orig)
print("Average F1: ", (metrics.f1_score(y_train_orig, y_pred_train_orig, average='micro') + metrics.f1_score(y_train_orig, y_pred_train_orig, average='macro'))/2)
# Out:
# Average F1:  0.8708453703849006

# %%
print(metrics.classification_report(y_train_orig, y_pred_train_orig))
# Out:
#                    precision    recall  f1-score   support
#
#        accountant       0.73      0.99      0.84       142
#         architect       0.83      0.94      0.88       252
#          attorney       0.93      0.92      0.92       851
#      chiropractor       0.66      1.00      0.80        68
#          comedian       0.88      1.00      0.93        77
#          composer       0.84      1.00      0.91       136
#           dentist       0.93      0.88      0.91       380
#         dietitian       0.80      0.97      0.88       111
#                dj       0.94      1.00      0.97        44
#         filmmaker       0.85      1.00      0.92       172
# interior_designer       0.93      1.00      0.96        37
#        journalist       0.79      0.93      0.85       501
#             model       0.98      0.98      0.98       179
#             nurse       0.82      0.81      0.82       501
#           painter       0.79      0.99      0.88       217
#         paralegal       0.88      1.00      0.93        50
#            pastor       0.77      1.00      0.87        71
#  personal_trainer       0.90      1.00      0.95        47
#      photographer       0.91      0.92      0.91       667
#         physician       0.86      0.81      0.84       993
#              poet       0.69      0.99      0.81       173
#         professor       0.96      0.79      0.87      3033
#      psychologist       0.78      0.73      0.75       483
#            rapper       0.96      1.00      0.98        53
# software_engineer       0.71      0.98      0.83       172
#           surgeon       0.76      0.79      0.78       360
#           teacher       0.70      0.87      0.78       425
#      yoga_teacher       0.79      1.00      0.88        33
#
#          accuracy                           0.86     10228
#         macro avg       0.83      0.94      0.88     10228
#      weighted avg       0.87      0.86      0.86     10228

# %%
from sklearn.svm import LinearSVC

# %%
model = LinearSVC(C=0.1, penalty="l2", dual=False, max_iter=10000).fit(X_train_vec, y_train)

# %%
X_val_vec, y_val = get_X_and_y(val_data)

y_pred = model.predict(X_val_vec)

print(metrics.accuracy_score(y_val, y_pred))
# Out:
# 0.7693510555121188

# %%
# calculate micro F1 and macro F1
print("Micro F1: ", metrics.f1_score(y_val, y_pred, average='micro'))
print("Macro F1: ", metrics.f1_score(y_val, y_pred, average='macro'))
# Out:
# Micro F1:  0.7693510555121188
# Macro F1:  0.6846925785709239

# %%
# get average
print("Average F1: ", (metrics.f1_score(y_val, y_pred, average='micro') + metrics.f1_score(y_val, y_pred, average='macro'))/2)
# Out:
# Average F1:  0.7270218170415214

# %%
# get prediction distribution when original label is professor
for occ in professions:
    print("#####################")
    print("Actual label: ", occ)
    print("#####################")
    selected_pred = y_pred[y_val==occ]
    print(pd.Series(selected_pred).value_counts())
    print()
# Out:
# #####################
# Actual label:  physician
# #####################
# physician           191
# surgeon              16
# nurse                 9
# professor             7
# attorney              4
# psychologist          4
# chiropractor          4
# dietitian             4
# journalist            2
# dentist               2
# personal_trainer      1
# architect             1
# pastor                1
# filmmaker             1
# dtype: int64
#
# #####################
# Actual label:  composer
# #####################
# composer        27
# psychologist     2
# poet             2
# rapper           1
# journalist       1
# dj               1
# dtype: int64
#
# #####################
# Actual label:  comedian
# #####################
# comedian        11
# teacher          2
# psychologist     1
# dietitian        1
# model            1
# poet             1
# journalist       1
# dtype: int64
#
# #####################
# Actual label:  professor
# #####################
# professor            595
# psychologist          27
# teacher               18
# nurse                 17
# physician             15
# surgeon               15
# attorney              15
# journalist            14
# architect             12
# software_engineer     11
# photographer           9
# poet                   9
# painter                9
# filmmaker              5
# composer               4
# personal_trainer       4
# accountant             3
# dietitian              3
# model                  2
# pastor                 2
# dtype: int64
#
# #####################
# Actual label:  journalist
# #####################
# journalist           80
# professor             7
# teacher               6
# attorney              4
# software_engineer     4
# photographer          3
# filmmaker             3
# painter               2
# architect             2
# composer              2
# comedian              1
# poet                  1
# psychologist          1
# accountant            1
# pastor                1
# dtype: int64
#
# #####################
# Actual label:  paralegal
# #####################
# paralegal    6
# attorney     6
# professor    1
# dtype: int64
#
# #####################
# Actual label:  nurse
# #####################
# nurse                97
# physician             7
# professor             3
# psychologist          3
# poet                  2
# teacher               2
# accountant            1
# attorney              1
# surgeon               1
# filmmaker             1
# software_engineer     1
# dtype: int64
#
# #####################
# Actual label:  attorney
# #####################
# attorney             219
# journalist             7
# teacher                5
# accountant             3
# filmmaker              3
# psychologist           3
# software_engineer      3
# architect              1
# comedian               1
# nurse                  1
# dietitian              1
# pastor                 1
# composer               1
# professor              1
# surgeon                1
# photographer           1
# physician              1
# dtype: int64
#
# #####################
# Actual label:  teacher
# #####################
# teacher         47
# professor        8
# poet             5
# journalist       4
# pastor           4
# composer         3
# photographer     3
# attorney         2
# chiropractor     2
# yoga_teacher     2
# nurse            2
# filmmaker        1
# model            1
# dtype: int64
#
# #####################
# Actual label:  psychologist
# #####################
# psychologist    89
# professor       11
# teacher          4
# journalist       3
# physician        2
# composer         1
# dentist          1
# nurse            1
# attorney         1
# yoga_teacher     1
# surgeon          1
# dtype: int64
#
# #####################
# Actual label:  dietitian
# #####################
# dietitian           18
# attorney             2
# surgeon              1
# teacher              1
# journalist           1
# personal_trainer     1
# physician            1
# dtype: int64
#
# #####################
# Actual label:  photographer
# #####################
# photographer         136
# journalist             4
# painter                3
# model                  3
# teacher                3
# software_engineer      2
# attorney               2
# psychologist           1
# dj                     1
# composer               1
# personal_trainer       1
# nurse                  1
# professor              1
# interior_designer      1
# accountant             1
# pastor                 1
# dtype: int64
#
# #####################
# Actual label:  surgeon
# #####################
# surgeon         60
# physician       14
# dentist          2
# nurse            2
# journalist       1
# poet             1
# dietitian        1
# professor        1
# chiropractor     1
# teacher          1
# architect        1
# dtype: int64
#
# #####################
# Actual label:  poet
# #####################
# poet            37
# teacher          3
# pastor           2
# professor        1
# attorney         1
# journalist       1
# photographer     1
# dtype: int64
#
# #####################
# Actual label:  rapper
# #####################
# rapper      6
# teacher     1
# attorney    1
# poet        1
# dtype: int64
#
# #####################
# Actual label:  software_engineer
# #####################
# software_engineer    31
# architect             5
# teacher               2
# dietitian             1
# accountant            1
# poet                  1
# model                 1
# professor             1
# chiropractor          1
# dtype: int64
#
# #####################
# Actual label:  architect
# #####################
# architect            49
# software_engineer     5
# professor             4
# painter               3
# teacher               2
# journalist            1
# attorney              1
# accountant            1
# nurse                 1
# photographer          1
# interior_designer     1
# model                 1
# dtype: int64
#
# #####################
# Actual label:  dentist
# #####################
# dentist         87
# physician        1
# chiropractor     1
# dtype: int64
#
# #####################
# Actual label:  model
# #####################
# model         34
# accountant     2
# nurse          1
# dentist        1
# filmmaker      1
# painter        1
# dtype: int64
#
# #####################
# Actual label:  pastor
# #####################
# pastor               11
# teacher               2
# architect             1
# interior_designer     1
# journalist            1
# dtype: int64
#
# #####################
# Actual label:  filmmaker
# #####################
# filmmaker       39
# journalist       3
# photographer     2
# teacher          2
# composer         1
# model            1
# dtype: int64
#
# #####################
# Actual label:  painter
# #####################
# painter         36
# photographer     2
# model            1
# attorney         1
# composer         1
# dtype: int64
#
# #####################
# Actual label:  accountant
# #####################
# accountant    27
# attorney       4
# architect      1
# professor      1
# painter        1
# journalist     1
# dtype: int64
#
# #####################
# Actual label:  dj
# #####################
# teacher         2
# photographer    1
# dj              1
# paralegal       1
# journalist      1
# painter         1
# rapper          1
# dtype: int64
#
# #####################
# Actual label:  yoga_teacher
# #####################
# yoga_teacher    12
# teacher          1
# chiropractor     1
# pastor           1
# dtype: int64
#
# #####################
# Actual label:  interior_designer
# #####################
# interior_designer    6
# photographer         1
# teacher              1
# architect            1
# accountant           1
# dtype: int64
#
# #####################
# Actual label:  chiropractor
# #####################
# chiropractor    11
# dentist          1
# physician        1
# psychologist     1
# dtype: int64
#
# #####################
# Actual label:  personal_trainer
# #####################
# personal_trainer    5
# psychologist        2
# yoga_teacher        1
# dietitian           1
# architect           1
# journalist          1
# dtype: int64

# %%
# classwise accuracy
print(metrics.classification_report(y_val, y_pred))
# Out:
#                    precision    recall  f1-score   support
#
#        accountant       0.66      0.77      0.71        35
#         architect       0.65      0.70      0.68        70
#          attorney       0.83      0.87      0.85       253
#      chiropractor       0.52      0.79      0.63        14
#          comedian       0.85      0.61      0.71        18
#          composer       0.66      0.79      0.72        34
#           dentist       0.93      0.98      0.95        89
#         dietitian       0.60      0.72      0.65        25
#                dj       0.33      0.12      0.18         8
#         filmmaker       0.72      0.81      0.76        48
# interior_designer       0.67      0.60      0.63        10
#        journalist       0.63      0.68      0.65       118
#             model       0.76      0.85      0.80        40
#             nurse       0.73      0.82      0.77       119
#           painter       0.64      0.88      0.74        41
#         paralegal       0.86      0.46      0.60        13
#            pastor       0.46      0.69      0.55        16
#  personal_trainer       0.42      0.45      0.43        11
#      photographer       0.85      0.84      0.84       162
#         physician       0.82      0.77      0.80       247
#              poet       0.62      0.80      0.70        46
#         professor       0.93      0.75      0.83       789
#      psychologist       0.66      0.77      0.71       115
#            rapper       0.75      0.67      0.71         9
# software_engineer       0.54      0.70      0.61        44
#           surgeon       0.63      0.71      0.67        85
#           teacher       0.45      0.56      0.50        84
#      yoga_teacher       0.75      0.80      0.77        15
#
#          accuracy                           0.77      2558
#         macro avg       0.68      0.71      0.68      2558
#      weighted avg       0.79      0.77      0.77      2558

# %%
modelNB = MultinomialNB(alpha=0.7).fit(X_train_vec, y_train)

# %%
X_val_vec, y_val = get_X_and_y(val_data)
y_pred = modelNB.predict_proba(X_val_vec)

# %%
y_pred[34]
# Out:
# array([1.61451516e-05, 1.14555535e-04, 1.41914486e-04, 6.58579909e-07,
#        2.76868991e-06, 2.30536118e-05, 4.18452365e-07, 4.37936328e-06,
#        9.80430998e-07, 2.36576495e-04, 1.05990511e-06, 3.40247891e-03,
#        4.54134197e-06, 2.12569229e-06, 8.00073639e-06, 2.63415476e-06,
#        9.77170195e-07, 6.48872660e-07, 8.83181342e-05, 4.20040483e-06,
#        2.78143100e-03, 9.92608402e-01, 1.58312434e-04, 1.24330630e-06,
#        1.37907712e-04, 1.31935576e-06, 2.54775713e-04, 1.72086514e-07])
